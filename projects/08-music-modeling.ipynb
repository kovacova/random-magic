# %% [markdown]
# <a href="https://colab.research.google.com/github/kovacova/random-magic/blob/master/projects/08-music-modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Music Modeling
#
# Siraj Raval's Tutorial
#
# [AI Composer Github Repo](https://github.com/llSourcell/AI_Composer)

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('S_f2qV2_U00')

# %% [markdown]
# ## Dependencies
# * Numpy (http://www.numpy.org/)
# * Tensorflow (https://github.com/tensorflow/tensorflow)
# * Python Midi (https://github.com/vishnubob/python-midi.git)
# * Mingus (https://github.com/bspaans/python-mingus)
