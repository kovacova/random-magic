# %% [markdown]
# <a href="https://colab.research.google.com/github/kovacova/random-magic/blob/master/projects/19-tweepy-basilica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install basilica -q

# %%
import tweepy
import basilica

# %%
TWITTER_CONSUMER_API_KEY = 'key'
TWITTER_CONSUMER_API_SECRET = 'key'
TWITTER_ACCESS_TOKEN = 'key'
TWITTER_ACCESS_TOKEN_SECRET = 'key'
# Add in key from Basilica
BASILICA_KEY = 'key'

# %%
TWITTER_AUTH = tweepy.OAuthHandler(TWITTER_CONSUMER_API_KEY,TWITTER_CONSUMER_API_SECRET)
TWITTER_AUTH.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
TWITTER = tweepy.API(TWITTER_AUTH)
BASILICA = basilica.Connection(BASILICA_KEY)

# %%
twitter_user = TWITTER.get_user('elonmusk')
twitter_user
# Out:
# User(_api=<tweepy.api.API object at 0x7f7dc3e85d68>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 28508435, 'friends_count': 82, 'listed_count': 51634, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 3979, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8958, 'lang': None, 'status': {'created_at': 'Fri Oct 04 03:12:10 +0000 2019', 'id': 1179957355628253185, 'id_str': '1179957355628253185', 'text': 'Excited about launching @NASA asteroid defense mission! #Armageddon69 https://t.co/6Hz4CKOLwU', 'truncated': False, 'entities': {'hashtags': [{'text': 'Armageddon69', 'indices': [56, 69]}], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [24, 29]}],
# ...

# %%
twitter_user.id
# Out:
# 44196397

# %%
tweets = twitter_user.timeline()
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f7dc3e85d68>, _json={'created_at': 'Fri Oct 04 03:12:10 +0000 2019', 'id': 1179957355628253185, 'id_str': '1179957355628253185', 'text': 'Excited about launching @NASA asteroid defense mission! #Armageddon69 https://t.co/6Hz4CKOLwU', 'truncated': False, 'entities': {'hashtags': [{'text': 'Armageddon69', 'indices': [56, 69]}], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [24, 29]}], 'urls': [{'url': 'https://t.co/6Hz4CKOLwU', 'expanded_url': 'https://twitter.com/sciguyspace/status/1116451957844193280', 'display_url': 'twitter.com/sciguyspace/st…', 'indices': [70, 93]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 44196397, 'id_str': '44196397'
# ...

# %%
tweets[0].text
# Out:
# 'Excited about launching @NASA asteroid defense mission! #Armageddon69 https://t.co/6Hz4CKOLwU'

# %%
tweets = twitter_user.timeline(count=200, 
                               exclude_replies=True, 
                               include_rts=False,
                               tweet_mode='extended')

tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f7dc3e85d68>, _json={'created_at': 'Fri Oct 04 03:12:10 +0000 2019', 'id': 1179957355628253185, 'id_str': '1179957355628253185', 'full_text': 'Excited about launching @NASA asteroid defense mission! #Armageddon69 https://t.co/6Hz4CKOLwU', 'truncated': False, 'display_text_range': [0, 69], 'entities': {'hashtags': [{'text': 'Armageddon69', 'indices': [56, 69]}], 'symbols': [], 'user_mentions': [{'screen_name': 'NASA', 'name': 'NASA', 'id': 11348282, 'id_str': '11348282', 'indices': [24, 29]}], 'urls': [{'url': 'https://t.co/6Hz4CKOLwU', 'expanded_url': 'https://twitter.com/sciguyspace/status/1116451957844193280', 'display_url': 'twitter.com/sciguyspace/st…', 'indices': [70, 93]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {
# ...

# %%
tweets[0].full_text
# Out:
# 'Excited about launching @NASA asteroid defense mission! #Armageddon69 https://t.co/6Hz4CKOLwU'

# %%
dir(tweets[2])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'display_text_range',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
# ...

# %%
embedding = BASILICA.embed_sentence(tweets[0].full_text, model='twitter')
embedding
# Out:
# [-0.28533,
#  -0.472091,
#  0.792991,
#  -0.583512,
#  0.783983,
#  0.0464133,
#  0.492019,
#  -0.071933,
#  0.176015,
#  -0.241419,
#  -0.838508,
#  -0.0632877,
#  -0.411778,
#  -0.288686,
#  -1.25039,
#  -0.262053,
#  0.332883,
#  -0.605111,
#  0.215432,
#  0.206082,
#  -0.180825,
#  -0.947076,
#  -0.531515,
#  -0.323967,
#  0.12456,
#  -0.339433,
#  0.112457,
#  -1.00024,
#  -0.830875,
#  -0.398637,
#  0.426765,
#  -0.121705,
#  -0.106359,
#  0.921591,
#  -0.219584,
#  0.298779,
#  -0.72078,
#  0.0458346,
#  0.539757,
#  0.04798,
#  -0.413286,
#  0.469557,
#  0.479756,
#  -0.923548,
#  -0.604913,
#  0.372759,
#  -2.3298,
#  0.219371,
#  -0.992979,
#  0.796731,
#  -0.00319605,
#  0.376518,
#  -0.6865,
#  0.28533,
#  0.862959,
#  0.413993,
#  -0.000477856,
#  -0.540549,
#  -0.785209,
#  -0.0985045,
#  0.0826337,
#  0.616489,
#  0.220745,
#  -0.40408,
#  0.525535,
#  0.096185,
#  0.545345,
#  0.13631,
#  -0.582699,
#  0.554593,
#  0.2755,
#  0.065552,
#  0.136694,
#  0.865956,
# ...

# %%
# TODO - integrate with Flask app & finish up the function

def add_user(username):
  # Get Twitter user data from tweepy API
  twitter_user = TWITTER.get_user(username)

  # Add user info to User table in database
  db_user = User(id=twitter_user.id, name=twitter_user.screen_name)
