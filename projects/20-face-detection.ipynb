# %% [markdown]
# <a href="https://colab.research.google.com/github/kovacova/random-magic/blob/master/projects/20-face-detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Detection Demo
#
# NOTE: Make sure to run the Colab with a GPU backend to prevent CUDA-related errors.
#
# [Tutorial](https://www.linkedin.com/learning/deep-learning-face-recognition/coding-face-detection)

# %%
# !pip3 install face_recognition -q
# Out:
#      |████████████████████████████████| 100.2MB 2.2MB/s
# ...

# %%
import PIL.Image
import PIL.ImageDraw
import face_recognition
from skimage import io

# Load the LOCAL jpg file into a numpy array
# image = face_recognition.load_image_file('aritzia.jpg')

# The same with an online image
image = io.imread('https://raw.githubusercontent.com/kovacova/random-magic/master/silliness/aritzia.jpg')

# Find all the faces in the image
face_location = face_recognition.face_locations(image)

number_of_faces = len(face_location)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline='red')
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 68, Left: 211, Bottom: 175, Right: 318

# %%
# Display the image
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=500x683 at 0x7FE15B1705C0>
